# %%
import pickle
import pandas as pd
# Step 1: Load the new dataset
data = pd.read_csv(r"C:\Users\suchi\Desktop\ELEVATE LABS\Classification-logisticreg\newdata.csv")
data
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         14.8          21.2            96.3        690            0.104
# 1         12.3          15.5            78.5        475            0.102
# 2         16.7          23.8           110.4        830            0.090
# 3         10.9          14.0            70.1        355            0.110
# 4         13.5          19.1            88.2        540            0.108
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0              0.16            0.17                0.080           0.22
# 1              0.12            0.10                0.060           0.19
# 2              0.13            0.14                0.070           0.21
# 3              0.08            0.07                0.030           0.15
# 4              0.14            0.15                0.065           0.20
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Load the trained model
with open("logistic_model.pkl", "rb") as f:
    model = pickle.load(f)

# Load the saved scaler
with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)

# %%
# Step 2: Scale the new data
scaled_data = scaler.transform(data)

# OPTIONAL: If your model used PCA, load and apply it
# with open("pca.pkl", "rb") as f:
#     pca = pickle.load(f)
# transformed_data = pca.transform(scaled_data)

# If no PCA, just use the scaled data
input_data = scaled_data  # or use 'transformed_data' if using PCA

# Step 3: Make predictions
predictions = model.predict(input_data)

print(predictions)
for i, pred in enumerate(predictions):
    label = "Malignant" if pred == 1 else "Benign"
    print(f"Sample {i + 1}: {label}")
# Out:
# [1 0 1 0 1]
# Sample 1: Malignant
# Sample 2: Benign
# Sample 3: Malignant
# Sample 4: Benign
# Sample 5: Malignant

# %%
# Out:
# [0 1]
